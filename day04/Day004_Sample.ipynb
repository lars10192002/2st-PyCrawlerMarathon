# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# id":"","url":"https://api.github.com/users/pull%5Bbot%5D","html_url":"https://github.com/apps/pull","followers_url":"https://api.github.com/users/pull%5Bbot%5D/followers","following_url":"https://api.github.com/users/pull%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/pull%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/pull%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/pull%5Bbot%5D/repos","events_url":"https://api.github.com/users/pull%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/pull%5Bbot%5D/received_events","type":"Bot","site_admin":false},"comments":0,"review_comments":0,"maintainer_can_modify":false,"commits":1,"additions":3,"deletions":3,"changed_files":1}},"public":true,"created_at":"2020-03-04T03:15:50Z"},{"id":"11671459381","type":"CreateEvent","actor":{"id":1458790,"login":"developersteve","display_login":"developersteve","gravatar_id":"","url":"https://api.github.com/users/developersteve","avatar_url":"https://avatars.githubusercontent.com/u/1458790?"},"repo":{"id":244796662,"name":"MelbIOT/CodeOfConduct","url":"https://api.github.com/repos/MelbIOT/CodeOfConduct"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-03-04T03:15:50Z","org":{"id":61768854,"login":"MelbIOT","gravatar_id":"","url":"https://api.github.com/orgs/MelbIOT","avatar_url":"https://avatars.githubusercontent.com/u/61768854?"}},{"id":"11671459377","type":"IssueCommentEvent","actor":{"id":26384082,"login":"stale[bot]","display_login":"stale","gravatar_id":"","url":"https://api.github.com/users/stale[bot]","avatar_url":"https://avatars.githubusercontent.com/u/26384082?"},"repo":{"id":6319157,"name":"taye/interact.js","url":"https://api.github.com/repos/taye/interact.js"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/taye/interact.js/issues/792","repository_url":"https://api.github.com/repos/taye/interact.js","labels_url":"https://api.github.com/repos/taye/interact.js/issues/792/labels{/name}","comments_url":"https://api.github.com/repos/taye/interact.js/issues/792/comments","events_url":"https://api.github.com/repos/taye/interact.js/issues/792/events","html_url":"https://github.com/taye/interact.js/issues/792","id":560134902,"node_id":"MDU6SXNzdWU1NjAxMzQ5MDI=","number":792,"title":"Resizing left edge makes element move out of place on v1.8.4","user":{"login":"huycan","id":4891835,"node_id":"MDQ6VXNlcjQ4OTE4MzU=","avatar_url":"https://avatars1.githubusercontent.com/u/4891835?v=4","gravatar_id":"","url":"https://api.github.com/users/huycan","html_url":"https://github.com/huycan","followers_url":"https://api.github.com/users/huycan/followers","following_url":"https://api.github.com/users/huycan/following{/other_user}","gists_url":"https://api.github.com/users/huycan/gists{/gist_id}","starred_url":"https://api.github.com/users/huycan/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/huycan/subscriptions","organizations_url":"https://api.github.com/users/huycan/orgs","repos_url":"https://api.github.com/users/huycan/repos","events_url":"https://api.github.com/users/huycan/events{/privacy}","received_events_url":"https://api.github.com/users/huycan/received_events","type":"User","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":1,"created_at":"2020-02-05T04:36:50Z","updated_at":"2020-03-04T03:15:50Z","closed_at":null,"author_association":"NONE","body":"Hi Taye,\\r\\n\\r\\nJust found your lib yesterday for my drag and resizing use case. It\'s awesome! Thanks for your hard work! I like the simplicity and how the library yields movement logic to users.\\r\\n\\r\\nI just want to let you k ...

# %%
import json

json.loads(r.text)
# Out:
# EwOlJlcG9zaXRvcnkyNDQ3OTU0OTc=',
#       'name': 'devops-essentials-sample-app',
#       'full_name': 'pvr20/devops-essentials-sample-app',
#       'private': False,
#       'owner': {'login': 'pvr20',
#        'id': 61768659,
#        'node_id': 'MDQ6VXNlcjYxNzY4NjU5',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/61768659?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/pvr20',
#        'html_url': 'https://github.com/pvr20',
#        'followers_url': 'https://api.github.com/users/pvr20/followers',
#        'following_url': 'https://api.github.com/users/pvr20/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/pvr20/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/pvr20/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/pvr20/subscriptions',
#        'organizations_url': 'https://api.github.com/users/pvr20/orgs',
#        'repos_url': 'https://api.github.com/users/pvr20/repos',
#        'events_url': 'https://api.github.com/users/pvr20/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/pvr20/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/pvr20/devops-essentials-sample-app',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app',
#       'forks_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/forks',
#       'keys_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/teams',
#       'hooks_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/hooks',
#       'issue_events_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/events',
#       'assignees_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/tags',
#       'blobs_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/languages',
#       'stargazers_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/stargazers',
#       'contributors_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/contributors',
#       'subscribers_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/subscribers',
#       'subscription_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/subscription',
#       'commits_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/merges',
#       'archive_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/downloads',
#       'issues_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/deployments',
#       'created_at': '2020-03-04T03:08:21Z',
#       'updated_at': '2020-03-04T03:08:23Z',
#       'pushed_at': '2020-02-27T19:46:17Z',
#       'git_url': 'git://github.com/pvr20/devops-essentials-sample-app.git',
#       'ssh_url': 'git@github.com:pvr20/devops-essentials-sample-app.git',
#       'clone_url': 'https://github.com/pvr20/devops-essentials-sample-app.git',
#       'svn_url': 'https://github.com/pvr20/devops-essentials-sample-app',
#       'homepage': None,
#       'size': 53,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'pvr20:master',
#      'ref': 'master',
#      'sha': 'dc95c531307bb3df387145a7b93a6f2e9ad0a872',
#      'user': {'login': 'pvr20',
#       'id': 61768659,
#       'node_id': 'MDQ6VXNlcjYxNzY4NjU5',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/61768659?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/pvr20',
#       'html_url': 'https://github.com/pvr20',
#       'followers_url': 'https://api.github.com/users/pvr20/followers',
#       'following_url': 'https://api.github.com/users/pvr20/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/pvr20/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/pvr20/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/pvr20/subscriptions',
#       'organizations_url': 'https://api.github.com/users/pvr20/orgs',
#       'repos_url': 'https://api.github.com/users/pvr20/repos',
#       'events_url': 'https://api.github.com/users/pvr20/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/pvr20/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 244795497,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDQ3OTU0OTc=',
#       'name': 'devops-essentials-sample-app',
#       'full_name': 'pvr20/devops-essentials-sample-app',
#       'private': False,
#       'owner': {'login': 'pvr20',
#        'id': 61768659,
#        'node_id': 'MDQ6VXNlcjYxNzY4NjU5',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/61768659?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/pvr20',
#        'html_url': 'https://github.com/pvr20',
#        'followers_url': 'https://api.github.com/users/pvr20/followers',
#        'following_url': 'https://api.github.com/users/pvr20/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/pvr20/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/pvr20/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/pvr20/subscriptions',
#        'organizations_url': 'https://api.github.com/users/pvr20/orgs',
#        'repos_url': 'https://api.github.com/users/pvr20/repos',
#        'events_url': 'https://api.github.com/users/pvr20/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/pvr20/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/pvr20/devops-essentials-sample-app',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app',
#       'forks_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/forks',
#       'keys_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/teams',
#       'hooks_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/hooks',
#       'issue_events_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/events',
#       'assignees_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/tags',
#       'blobs_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/languages',
#       'stargazers_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/stargazers',
#       'contributors_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/contributors',
#       'subscribers_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/subscribers',
#       'subscription_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/subscription',
#       'commits_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/merges',
#       'archive_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/downloads',
#       'issues_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/deployments',
#       'created_at': '2020-03-04T03:08:21Z',
#       'updated_at': '2020-03-04T03:08:23Z',
#       'pushed_at': '2020-02-27T19:46:17Z',
#       'git_url': 'git://github.com/pvr20/devops-essentials-sample-app.git',
#       'ssh_url': 'git@github.com:pvr20/devops-essentials-sample-app.git',
#       'clone_url': 'https://github.com/pvr20/devops-essentials-sample-app.git',
#       'svn_url': 'https://github.com/pvr20/devops-essentials-sample-app',
#       'homepage': None,
#       'size': 53,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/pulls/1'},
#      'html': {'href': 'https://github.com/pvr20/devops-essentials-sample-app/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/pvr20/devops-essentials-sample-app/statuses/02fc50084a6483f16828fcc98c0a086797d0d764'}},
#     'author_association': 'OWNER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 2,
#     'deletions': 2,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-03-04T03:13:57Z'},
#  {'id': '11671450217',
#   'type': 'IssuesEvent',
#   'actor': {'id': 39754219,
#    'login': 'alex-zador',
#    'display_login': 'alex-zador',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alex-zador',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39754219?'},
#   'repo': {'id': 65600975,
#    'name': 'pytorch/pytorch',
#    'url': 'https://api.github.com/repos/pytorch/pytorch'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/pytorch/pytorch/issues/34124',
#     'repository_url': 'https://api.github.com/repos/pytorch/pytorch',
#     'labels_url': 'https://api.github.com/repos/pytorch/pytorch/issues/34124/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/pytorch/pytorch/issues/34124/comments',
#     'events_url': 'https://api.github.com/repos/pytorch/pytorch/issues/34124/events',
#     'html_url': 'https://github.com/pytorch/pytorch/issues/34124',
#     'id': 574527585,
#     'node_id': 'MDU6SXNzdWU1NzQ1Mjc1ODU=',
#     'number': 34124,
#     'title': 'Windwos Install libtorch issue',
#     'user': {'login': 'alex-zador',
#      'id': 39754219,
#      'node_id': 'MDQ6VXNlcjM5NzU0MjE5',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/39754219?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/alex-zador',
#      'html_url': 'https://github.com/alex-zador',
#      'followers_url': 'https://api.github.com/users/alex-zador/followers',
#      'following_url': 'https://api.github.com/users/alex-zador/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/alex-zador/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/alex-zador/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/alex-zador/subscriptions',
#      'organizations_url': 'https://api.github.com/users/alex-zador/orgs',
#      'repos_url': 'https://api.github.com/users/alex-zador/repos',
#      'events_url': 'https://api.github.com/users/alex-zador/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/alex-zador/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 778855555,
#       'node_id': 'MDU6TGFiZWw3Nzg4NTU1NTU=',
#       'url': 'https://api.github.com/repos/pytorch/pytorch/labels/module:%20build',
#       'name': 'module: build',
#       'color': 'f7e101',
#       'default': False,
#       'description': 'Build system issues'},
#      {'id': 790080431,
#       'node_id': 'MDU6TGFiZWw3OTAwODA0MzE=',
#       'url': 'https://api.github.com/repos/pytorch/pytorch/labels/module:%20windows',
#       'name': 'module: windows',
#       'color': 'f7e101',
#       'default': False,
#       'description': 'Windows support for PyTorch'},
#      {'id': 1301347167,
#       'node_id': 'MDU6TGFiZWwxMzAxMzQ3MTY3',
#       'url': 'https://api.github.com/repos/pytorch/pytorch/labels/triaged',
#       'name': 'triaged',
#       'color': '006b75',
#       'default': False,
#       'description': 'This issue has been looked at a team member, and triaged and prioritized into an appropriate module'}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2020-03-03T09:25:21Z',
#     'updated_at': '2020-03-04T03:13:57Z',
#     'closed_at': '2020-03-04T03:13:56Z',
#     'author_association': 'NONE',
#     'body': "When trying install libtorch as in https://pytorch.org/cppdocs/installing.html I've got error:\r\n C:\\libtorch\\include\\ATen/core/PhiloxRNGEngine.h(183): error C2719: 'ctr': formal parameter with requested alignment o\r\nf 16 won't be aligned [C:\\Users\\alex\\Desktop\\Uni 201x\\Uni19-20\\МИШ\\CTorch\\CTorch\\build\\CTorch.vcxproj]\r\n  C:\\libtorch\\include\\ATen/core/PhiloxRNGEngine.h(183): error C2719: 'in_key': formal parameter with requested alignmen\r\nt of 16 won't be aligned [C:\\Users\\alex\\Desktop\\Uni 201x\\Uni19-20\\МИШ\\CTorch\\CTorch\\build\\CTorch.vcxproj]\r\n\r\nHow can I overcome it and what is the reason? \n\ncc @peterjc123"}},
#   'public': True,
#   'created_at': '2020-03-04T03:13:57Z',
#   'org': {'id': 21003710,
#    'login': 'pytorch',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pytorch',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21003710?'}},
#  {'id': '11671450216',
#   'type': 'PushEvent',
#   'actor': {'id': 52130319,
#    'login': 'cliffhuang0611',
#    'display_login': 'cliffhuang0611',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cliffhuang0611',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52130319?'},
#   'repo': {'id': 242917777,
#    'name': 'cliffhuang0611/aws_loadbalancer',
#    'url': 'https://api.github.com/repos/cliffhuang0611/aws_loadbalancer'},
#   'payload': {'push_id': 4714824508,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8dc6c92f102636c172644a5f763c928779b9c026',
#    'before': 'a48715fbb5cd300ebd769653bb3f0df79b92e434',
#    'commits': [{'sha': '8dc6c92f102636c172644a5f763c928779b9c026',
#      'author': {'email': 'huang@techfirm.co.jp', 'name': 'HUANG SONG YING'},
#      'message': 'updated to version 14',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cliffhuang0611/aws_loadbalancer/commits/8dc6c92f102636c172644a5f763c928779b9c026'}]},
#   'public': True,
#   'created_at': '2020-03-04T03:13:57Z'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e5f1e39-705abb0a02ebb87397e945b0'},
#  'origin': '140.115.53.96',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e5f1e6d-c0b63ad1dd34235901f15de6'},
#  'json': None,
#  'origin': '140.115.53.96',
#  'url': 'http://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e5f1e70-9c2ea964e393334c1094246c'},
#  'json': None,
#  'origin': '140.115.53.96',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
