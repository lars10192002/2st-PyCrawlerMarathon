# %% [markdown]
# # Python 下載XML檔案與解析
#
#
# * 了解 xml 檔案格式與內容
# * 能夠利用套件存取 xml 格式的檔案

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異
#
# * 根據範例檔案的結果：
#     1. 請問高雄市有多少地區有溫度資料？
#     2. 請取出每一個地區所記錄的第一個時間點跟溫度
#     3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %% [markdown]
# ### 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異

# %%
File I/O : 讀取的是原始含有標籤的xml檔案
xmltodict : 會把所有資料用一個大字典包起來，相同層級的子標籤用元祖和列表來表示，整體就像是一個json檔案

# %% [markdown]
# ### 根據範例檔案的結果：
#
# 1. 請問高雄市有多少地區有溫度資料？
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %%
# 1. 請問高雄市有多少地區有溫度資料？
import xmltodict

# 存取檔案

doc = dict(xmltodict.parse(xml))
a = doc['cwbopendata']['dataset']['locations']['location']
print(len(a))
print(type(a))
print('--------------------------------------------------------------------')
# print(iter(a))
print(type(iter(a)))
print('--------------------------------------------------------------------')
row = next(iter(a))
# print(row)
print(type(row))
# 用迴圈存取我們的資訊
# datas = doc['cwbopendata']['dataset']
# print(dir(str))
# Out:
# 38
# <class 'list'>
# --------------------------------------------------------------------
# <class 'list_iterator'>
# --------------------------------------------------------------------
# <class 'collections.OrderedDict'>

# %% [markdown]
# # 2. 請取出每一個地區所記錄的第一個時間點跟溫度

# %%
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度

for i in k:
    print(i['locationName'])
    print(i['weatherElement'][0]['time'][0]['dataTime'])
    print(i['weatherElement'][0]['time'][0]['elementValue']['value'])
# Out:
# 鹽埕區
# 2020-03-02T12:00:00+08:00
# 25
# 鼓山區
# 2020-03-02T12:00:00+08:00
# 25
# 左營區
# 2020-03-02T12:00:00+08:00
# 25
# 楠梓區
# 2020-03-02T12:00:00+08:00
# 26
# 三民區
# 2020-03-02T12:00:00+08:00
# 25
# 新興區
# 2020-03-02T12:00:00+08:00
# 26
# 前金區
# 2020-03-02T12:00:00+08:00
# 25
# 苓雅區
# 2020-03-02T12:00:00+08:00
# 26
# 前鎮區
# 2020-03-02T12:00:00+08:00
# 26
# 旗津區
# 2020-03-02T12:00:00+08:00
# 25
# 小港區
# 2020-03-02T12:00:00+08:00
# 26
# 鳳山區
# 2020-03-02T12:00:00+08:00
# 27
# 林園區
# 2020-03-02T12:00:00+08:00
# 27
# 大寮區
# 2020-03-02T12:00:00+08:00
# 27
# 大樹區
# 2020-03-02T12:00:00+08:00
# 28
# 大社區
# 2020-03-02T12:00:00+08:00
# 27
# 仁武區
# 2020-03-02T12:00:00+08:00
# 26
# 鳥松區
# 2020-03-02T12:00:00+08:00
# 27
# 岡山區
# 2020-03-02T12:00:00+08:00
# 26
# 橋頭區
# 2020-03-02T12:00:00+08:00
# 26
# 燕巢區
# 2020-03-02T12:00:00+08:00
# 26
# 田寮區
# 2020-03-02T12:00:00+08:00
# 27
# 阿蓮區
# 2020-03-02T12:00:00+08:00
# 26
# 路竹區
# 2020-03-02T12:00:00+08:00
# 27
# 湖內區
# 2020-03-02T12:00:00+08:00
# 25
# 茄萣區
# ...

# %%
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度 (用iter)

for i in k:
    print(i['locationName'])
    first = next(iter(i['weatherElement']))
    sec = next(iter(first['time']))
    print(sec.get('dataTime'))
    print(sec.get('elementValue').get('value'))
# Out:
# 鹽埕區
# 2020-03-02T12:00:00+08:00
# 25
# 鼓山區
# 2020-03-02T12:00:00+08:00
# 25
# 左營區
# 2020-03-02T12:00:00+08:00
# 25
# 楠梓區
# 2020-03-02T12:00:00+08:00
# 26
# 三民區
# 2020-03-02T12:00:00+08:00
# 25
# 新興區
# 2020-03-02T12:00:00+08:00
# 26
# 前金區
# 2020-03-02T12:00:00+08:00
# 25
# 苓雅區
# 2020-03-02T12:00:00+08:00
# 26
# 前鎮區
# 2020-03-02T12:00:00+08:00
# 26
# 旗津區
# 2020-03-02T12:00:00+08:00
# 25
# 小港區
# 2020-03-02T12:00:00+08:00
# 26
# 鳳山區
# 2020-03-02T12:00:00+08:00
# 27
# 林園區
# 2020-03-02T12:00:00+08:00
# 27
# 大寮區
# 2020-03-02T12:00:00+08:00
# 27
# 大樹區
# 2020-03-02T12:00:00+08:00
# 28
# 大社區
# 2020-03-02T12:00:00+08:00
# 27
# 仁武區
# 2020-03-02T12:00:00+08:00
# 26
# 鳥松區
# 2020-03-02T12:00:00+08:00
# 27
# 岡山區
# 2020-03-02T12:00:00+08:00
# 26
# 橋頭區
# 2020-03-02T12:00:00+08:00
# 26
# 燕巢區
# 2020-03-02T12:00:00+08:00
# 26
# 田寮區
# 2020-03-02T12:00:00+08:00
# 27
# 阿蓮區
# 2020-03-02T12:00:00+08:00
# 26
# 路竹區
# 2020-03-02T12:00:00+08:00
# 27
# 湖內區
# 2020-03-02T12:00:00+08:00
# 25
# 茄萣區
# ...

# %%
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %%
# print(type(k))
print(type(k[0]['locationName']))
for h in k[0]['weatherElement']:
    # print(next(iter(h['time'])))
    # print(h['time'])
    # print(dir(h['time']))
    for y in h['time']:
        print(y.get('dataTime'))
        print(y.get('elementValue').get('value'))
# Out:
# <class 'str'>
# 2020-03-02T12:00:00+08:00
# 25
# 2020-03-02T15:00:00+08:00
# 25
# 2020-03-02T18:00:00+08:00
# 24
# 2020-03-02T21:00:00+08:00
# 22
# 2020-03-03T00:00:00+08:00
# 21
# 2020-03-03T03:00:00+08:00
# 20
# 2020-03-03T06:00:00+08:00
# 20
# 2020-03-03T09:00:00+08:00
# 22
# 2020-03-03T12:00:00+08:00
# 25
# 2020-03-03T15:00:00+08:00
# 26
# 2020-03-03T18:00:00+08:00
# 24
# 2020-03-03T21:00:00+08:00
# 23
# 2020-03-04T00:00:00+08:00
# 22
# 2020-03-04T03:00:00+08:00
# 21
# 2020-03-04T06:00:00+08:00
# 20
# 2020-03-04T09:00:00+08:00
# 22
# 2020-03-04T12:00:00+08:00
# 26
# 2020-03-04T15:00:00+08:00
# 26
# 2020-03-04T18:00:00+08:00
# 24
# 2020-03-04T21:00:00+08:00
# 22
# 2020-03-05T00:00:00+08:00
# 21
# 2020-03-05T03:00:00+08:00
# 20
# 2020-03-05T06:00:00+08:00
# 19
# 2020-03-05T09:00:00+08:00
# 21
# 2020-03-02T12:00:00+08:00
# 19
# 2020-03-02T15:00:00+08:00
# 18
# 2020-03-02T18:00:00+08:00
# 18
# 2020-03-02T21:00:00+08:00
# 17
# 2020-03-03T00:00:00+08:00
# 17
# ...

# %%
print(k[0]['locationName'])
for z in k[0]['weatherElement']:
    for y in z['time']:
        print(y['dataTime'])
        print(y['elementValue']['value'])
# Out:
# 鹽埕區
# 2020-03-02T12:00:00+08:00
# 25
# 2020-03-02T15:00:00+08:00
# 25
# 2020-03-02T18:00:00+08:00
# 24
# 2020-03-02T21:00:00+08:00
# 22
# 2020-03-03T00:00:00+08:00
# 21
# 2020-03-03T03:00:00+08:00
# 20
# 2020-03-03T06:00:00+08:00
# 20
# 2020-03-03T09:00:00+08:00
# 22
# 2020-03-03T12:00:00+08:00
# 25
# 2020-03-03T15:00:00+08:00
# 26
# 2020-03-03T18:00:00+08:00
# 24
# 2020-03-03T21:00:00+08:00
# 23
# 2020-03-04T00:00:00+08:00
# 22
# 2020-03-04T03:00:00+08:00
# 21
# 2020-03-04T06:00:00+08:00
# 20
# 2020-03-04T09:00:00+08:00
# 22
# 2020-03-04T12:00:00+08:00
# 26
# 2020-03-04T15:00:00+08:00
# 26
# 2020-03-04T18:00:00+08:00
# 24
# 2020-03-04T21:00:00+08:00
# 22
# 2020-03-05T00:00:00+08:00
# 21
# 2020-03-05T03:00:00+08:00
# 20
# 2020-03-05T06:00:00+08:00
# 19
# 2020-03-05T09:00:00+08:00
# 21
# 2020-03-02T12:00:00+08:00
# 19
# 2020-03-02T15:00:00+08:00
# 18
# 2020-03-02T18:00:00+08:00
# 18
# 2020-03-02T21:00:00+08:00
# 17
# 2020-03-03T00:00:00+08:00
# 17
# 2020-03-03T03:00:00+08:00
# 16
# ...
